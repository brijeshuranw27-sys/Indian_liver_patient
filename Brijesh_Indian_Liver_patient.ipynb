# %% [markdown]
# # Liver patient prediction
#
# This notebook mirrors the reproducible training workflow in `train_model.py`.

# %%
import pandas as pd
from model import FEATURES
data = pd.read_csv('liver_patient.csv')
data[FEATURES].head()

# %% [markdown]
# Run `python train_model.py` from the project folder to create the serialized model artifact.
